# %%
import tensorflow as tf
import pickle
from util import *
from load_data import load_input_file, build_combined_input
from NN_train import *
path_tosave = 'Models/V05_SvsS_Final_6Vars'
path_SvsS = path_tosave + '/SvsS/'
path_SvsB = path_tosave + '/SvsB/'
mkdir_p(path_tosave)
mkdir_p(path_SvsS)
mkdir_p(path_SvsB)
features_to_ignore = []
#features_to_ignore = ["DPhill_SS", "DeltaR_min_lep_bjet77", "DRll01","HT_jets","sumPsbtag","met_met","Mll01","DEtall_SS","jet_pseudoscore_DL1r2","nJets_OR_DL1r_77","sumPsbtag77"]

# %%
samples, feature_names, class_names, class_no = load_input_file('data/V05_SvsS.h5', features_to_ignore)
# Out:
# Found 23 features on the dataset 23 features were loaded:
#
# DEtall_SS
# DPhill_SS
# DRll01
# HT_jets
# HT_lep
# Mll01
# MtLepMet
# jet_pseudoscore_DL1r0
# jet_pseudoscore_DL1r1
# jet_pseudoscore_DL1r2
# DeltaR_max_lep_bjet77
# DeltaR_min_lep_bjet77
# DRjj_lead
# jet_pt0_nofwd
# met_met
# total_charge
# nJets_OR
# nJets_OR_DL1r_77
# sumPsbtag
# sumPsbtag77
# randomRunNumber
# weight_cuu_0p00_cqu1_0p10_cqu8_0p20
# weight_cuu_0p04

# %%
# Maunal processing of the Signal vs Signal Data
targets = []
sample0, *other = samples
targets.extend( np.ones( sample0.data().shape[0] ) * sample0.class_label() )
inputs = sample0.data()
targets = np.array(targets, dtype = int )
weights = inputs[:,-1]
inputs = inputs[:,0:-1]
targets = targets[np.where((weights<1) &(weights>0))]
inputs  = inputs[np.where((weights<1) &(weights>0))]
weights = weights[np.where((weights<1) &(weights>0))]
data_len = inputs.shape[0]

# %%
weights_cuu = inputs[:,-1]
weights_cqu = inputs[:,-2]
weights_cuu_int = (inputs[:,-1] * 10).astype(int)
weights_cqu_int = (inputs[:,-2] * 10).astype(int)
Number_org = inputs[:,-3]
inputs = inputs[:,0:-3]
feature_names = feature_names[0:-3]
feature_names
# Out:
# ['DEtall_SS',
#  'DPhill_SS',
#  'DRll01',
#  'HT_jets',
#  'HT_lep',
#  'Mll01',
#  'MtLepMet',
#  'jet_pseudoscore_DL1r0',
#  'jet_pseudoscore_DL1r1',
#  'jet_pseudoscore_DL1r2',
#  'DeltaR_max_lep_bjet77',
#  'DeltaR_min_lep_bjet77',
#  'DRjj_lead',
#  'jet_pt0_nofwd',
#  'met_met',
#  'total_charge',
#  'nJets_OR',
#  'nJets_OR_DL1r_77',
#  'sumPsbtag',
#  'sumPsbtag77']

# %%
reweighted_inputs = np.zeros([weights_cuu_int.sum()+weights_cqu_int.sum(),inputs.shape[1]])
targets = np.concatenate([np.zeros(weights_cuu_int.sum()), np.ones(weights_cqu_int.sum())])
Numbers = np.zeros([weights_cuu_int.sum()+weights_cqu_int.sum()])
counter = 0
for i in range(weights_cuu_int.shape[0]):
    for j in range(weights_cuu_int[i]):
        reweighted_inputs[counter,:] = inputs[i,:]
        Numbers[counter] = Number_org[i]
        counter +=1
for i in range(weights_cqu_int.shape[0]):
    for j in range(weights_cqu_int[i]):
        reweighted_inputs[counter,:] = inputs[i,:]
        Numbers[counter] = Number_org[i]
        counter +=1

# %%
scaler = StandardScaler().fit(reweighted_inputs)
input_scaled = scaler.transform(reweighted_inputs)
pickle.dump(scaler, open(path_tosave + '/scaler.pkl','wb'))

# %%
def Fold_Odd_Even_changed(input, targets, Number):
    input_odd = input[Number % 2 == 1]
    targets_odd = targets[Number % 2 == 1]
    input_even = input[Number % 2 == 0]
    targets_even = targets[Number % 2 == 0]
    return (input_odd, targets_odd), (input_even, targets_even)

# %%
odd, even = Fold_Odd_Even_changed(input_scaled, targets, Numbers)

# %%
def Train_Odd_Even_changed(odd, even, n_epochs = 400, batch_size = 2000):
    fit_history_list = []
    model_list = []
    input_shape = odd[0].shape[1]

    lr_schedule = tf.keras.callbacks.LearningRateScheduler(lr_step_decay)

    X_odd, X_val_odd, y_odd, y_val_odd, = train_test_split(odd[0], odd[1], test_size=0.2)
    X_even, X_val_even, y_even, y_val_even, = train_test_split(even[0], even[1], test_size=0.2)

    model_odd = Create_Model_basic(input_shape)
    model_even = Create_Model_basic(input_shape)
    fit_history_odd = model_odd.fit(X_odd, y_odd, epochs = n_epochs, shuffle = True, batch_size = batch_size, validation_data=(X_val_odd, y_val_odd), verbose=1 ,callbacks=[tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 100, verbose = True, min_delta = 0.001),lr_schedule]) #
    fit_history_even = model_even.fit(X_even, y_even, epochs = n_epochs, shuffle = True, batch_size = batch_size, validation_data=(X_val_even, y_val_even), verbose=1 ,callbacks=[tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 100, verbose = True, min_delta = 0.001),lr_schedule]) #

    return fit_history_odd, model_odd, fit_history_even, model_even

# %%
input_shape = odd[0].shape[1]
n_epochs = 200
batch_size = 20000

# %%
history_odd, model_odd, history_even, model_even= Train_Odd_Even_changed(odd, even, n_epochs = n_epochs, batch_size = batch_size)
history_list = [history_odd, history_even]
Plot_Metrics_KFold(history_list, path_SvsS) 

Save_Model(model_odd, path_tosave, "_odd")
Save_Model(model_even, path_tosave, "_even")
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               2688
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 13,697
# Trainable params: 13,697
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 20)]              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               2688
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 13,697
# Trainable params: 13,697
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3137983 samples, validate on 784496 samples
# Epoch 1/200
# 3120000/3137983 [============================>.] - ETA: 0s - loss: 0.6204 - accuracy: 0.6605
# /home/avdgraaf/.local/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 3137983/3137983 [==============================] - 4s 1us/sample - loss: 0.6204 - accuracy: 0.6606 - val_loss: 0.6110 - val_accuracy: 0.6665
# Epoch 2/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6106 - accuracy: 0.6664 - val_loss: 0.6091 - val_accuracy: 0.6677
# Epoch 3/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6087 - accuracy: 0.6674 - val_loss: 0.6086 - val_accuracy: 0.6678
# Epoch 4/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6082 - accuracy: 0.6678 - val_loss: 0.6079 - val_accuracy: 0.6680
# Epoch 5/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6080 - accuracy: 0.6678 - val_loss: 0.6069 - val_accuracy: 0.6693
# Epoch 6/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6072 - accuracy: 0.6685 - val_loss: 0.6068 - val_accuracy: 0.6690
# Epoch 7/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6071 - accuracy: 0.6685 - val_loss: 0.6071 - val_accuracy: 0.6688
# Epoch 8/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6069 - accuracy: 0.6686 - val_loss: 0.6069 - val_accuracy: 0.6691
# Epoch 9/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6068 - accuracy: 0.6687 - val_loss: 0.6071 - val_accuracy: 0.6687
# Epoch 10/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6064 - accuracy: 0.6690 - val_loss: 0.6075 - val_accuracy: 0.6681
# Epoch 11/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6065 - accuracy: 0.6688 - val_loss: 0.6061 - val_accuracy: 0.6694
# Epoch 12/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6061 - accuracy: 0.6692 - val_loss: 0.6065 - val_accuracy: 0.6687
# Epoch 13/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6061 - accuracy: 0.6693 - val_loss: 0.6056 - val_accuracy: 0.6701
# Epoch 14/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6059 - accuracy: 0.6693 - val_loss: 0.6059 - val_accuracy: 0.6692
# Epoch 15/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6058 - accuracy: 0.6695 - val_loss: 0.6053 - val_accuracy: 0.6698
# Epoch 16/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6056 - accuracy: 0.6696 - val_loss: 0.6057 - val_accuracy: 0.6696
# Epoch 17/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6057 - accuracy: 0.6695 - val_loss: 0.6062 - val_accuracy: 0.6691
# Epoch 18/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6055 - accuracy: 0.6694 - val_loss: 0.6056 - val_accuracy: 0.6695
# Epoch 19/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6055 - accuracy: 0.6696 - val_loss: 0.6057 - val_accuracy: 0.6696
# Epoch 20/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6055 - accuracy: 0.6695 - val_loss: 0.6060 - val_accuracy: 0.6691
# Epoch 21/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6053 - accuracy: 0.6698 - val_loss: 0.6052 - val_accuracy: 0.6697
# Epoch 22/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6050 - accuracy: 0.6699 - val_loss: 0.6052 - val_accuracy: 0.6698
# Epoch 23/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6050 - accuracy: 0.6699 - val_loss: 0.6050 - val_accuracy: 0.6702
# Epoch 24/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6049 - accuracy: 0.6700 - val_loss: 0.6055 - val_accuracy: 0.6693
# Epoch 25/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6049 - accuracy: 0.6700 - val_loss: 0.6046 - val_accuracy: 0.6701
# Epoch 26/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6064 - accuracy: 0.6685 - val_loss: 0.6081 - val_accuracy: 0.6685
# Epoch 27/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6065 - accuracy: 0.6688 - val_loss: 0.6071 - val_accuracy: 0.6684
# Epoch 28/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6060 - accuracy: 0.6691 - val_loss: 0.6069 - val_accuracy: 0.6682
# Epoch 29/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6059 - accuracy: 0.6692 - val_loss: 0.6056 - val_accuracy: 0.6697
# Epoch 30/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6058 - accuracy: 0.6693 - val_loss: 0.6072 - val_accuracy: 0.6676
# Epoch 31/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6057 - accuracy: 0.6693 - val_loss: 0.6056 - val_accuracy: 0.6695
# Epoch 32/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6059 - accuracy: 0.6692 - val_loss: 0.6061 - val_accuracy: 0.6690
# Epoch 33/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6057 - accuracy: 0.6692 - val_loss: 0.6057 - val_accuracy: 0.6693
# Epoch 34/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6059 - accuracy: 0.6692 - val_loss: 0.6054 - val_accuracy: 0.6696
# Epoch 35/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6053 - accuracy: 0.6696 - val_loss: 0.6052 - val_accuracy: 0.6696
# Epoch 36/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6055 - accuracy: 0.6693 - val_loss: 0.6064 - val_accuracy: 0.6681
# Epoch 37/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6053 - accuracy: 0.6694 - val_loss: 0.6053 - val_accuracy: 0.6697
# Epoch 38/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6054 - accuracy: 0.6694 - val_loss: 0.6052 - val_accuracy: 0.6696
# Epoch 39/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6051 - accuracy: 0.6697 - val_loss: 0.6051 - val_accuracy: 0.6700
# Epoch 40/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6053 - accuracy: 0.6695 - val_loss: 0.6053 - val_accuracy: 0.6692
# Epoch 41/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6051 - accuracy: 0.6696 - val_loss: 0.6049 - val_accuracy: 0.6701
# Epoch 42/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6050 - accuracy: 0.6698 - val_loss: 0.6048 - val_accuracy: 0.6700
# Epoch 43/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6050 - accuracy: 0.6698 - val_loss: 0.6047 - val_accuracy: 0.6701
# Epoch 44/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6049 - accuracy: 0.6698 - val_loss: 0.6048 - val_accuracy: 0.6701
# Epoch 45/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6048 - accuracy: 0.6698 - val_loss: 0.6051 - val_accuracy: 0.6697
# Epoch 46/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6047 - accuracy: 0.6700 - val_loss: 0.6046 - val_accuracy: 0.6702
# Epoch 47/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6049 - accuracy: 0.6698 - val_loss: 0.6050 - val_accuracy: 0.6699
# Epoch 48/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6047 - accuracy: 0.6699 - val_loss: 0.6044 - val_accuracy: 0.6704
# Epoch 49/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6046 - accuracy: 0.6699 - val_loss: 0.6046 - val_accuracy: 0.6701
# Epoch 50/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6045 - accuracy: 0.6700 - val_loss: 0.6043 - val_accuracy: 0.6703
# Epoch 51/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6037 - accuracy: 0.6707 - val_loss: 0.6041 - val_accuracy: 0.6706
# Epoch 52/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6037 - accuracy: 0.6707 - val_loss: 0.6039 - val_accuracy: 0.6710
# Epoch 53/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6037 - accuracy: 0.6707 - val_loss: 0.6037 - val_accuracy: 0.6710
# Epoch 54/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6035 - accuracy: 0.6708 - val_loss: 0.6039 - val_accuracy: 0.6706
# Epoch 55/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6035 - accuracy: 0.6709 - val_loss: 0.6037 - val_accuracy: 0.6707
# Epoch 56/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6035 - accuracy: 0.6708 - val_loss: 0.6036 - val_accuracy: 0.6707
# Epoch 57/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6034 - accuracy: 0.6710 - val_loss: 0.6038 - val_accuracy: 0.6708
# Epoch 58/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6034 - accuracy: 0.6708 - val_loss: 0.6035 - val_accuracy: 0.6707
# Epoch 59/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6034 - accuracy: 0.6708 - val_loss: 0.6037 - val_accuracy: 0.6708
# Epoch 60/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6033 - accuracy: 0.6709 - val_loss: 0.6035 - val_accuracy: 0.6709
# Epoch 61/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6033 - accuracy: 0.6709 - val_loss: 0.6036 - val_accuracy: 0.6710
# Epoch 62/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6033 - accuracy: 0.6710 - val_loss: 0.6036 - val_accuracy: 0.6710
# Epoch 63/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6032 - accuracy: 0.6710 - val_loss: 0.6034 - val_accuracy: 0.6708
# Epoch 64/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6031 - accuracy: 0.6710 - val_loss: 0.6037 - val_accuracy: 0.6706
# Epoch 65/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6032 - accuracy: 0.6709 - val_loss: 0.6035 - val_accuracy: 0.6708
# Epoch 66/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6031 - accuracy: 0.6709 - val_loss: 0.6035 - val_accuracy: 0.6710
# Epoch 67/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6031 - accuracy: 0.6710 - val_loss: 0.6036 - val_accuracy: 0.6708
# Epoch 68/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6031 - accuracy: 0.6711 - val_loss: 0.6035 - val_accuracy: 0.6707
# Epoch 69/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6711 - val_loss: 0.6033 - val_accuracy: 0.6709
# Epoch 70/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6031 - accuracy: 0.6710 - val_loss: 0.6034 - val_accuracy: 0.6711
# Epoch 71/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6711 - val_loss: 0.6033 - val_accuracy: 0.6707
# Epoch 72/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6712 - val_loss: 0.6034 - val_accuracy: 0.6709
# Epoch 73/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6029 - accuracy: 0.6711 - val_loss: 0.6035 - val_accuracy: 0.6711
# Epoch 74/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6710 - val_loss: 0.6033 - val_accuracy: 0.6710
# Epoch 75/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6029 - accuracy: 0.6713 - val_loss: 0.6032 - val_accuracy: 0.6710
# Epoch 76/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6713 - val_loss: 0.6032 - val_accuracy: 0.6710
# Epoch 77/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6712 - val_loss: 0.6036 - val_accuracy: 0.6707
# Epoch 78/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6712 - val_loss: 0.6033 - val_accuracy: 0.6711
# Epoch 79/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6712 - val_loss: 0.6032 - val_accuracy: 0.6710
# Epoch 80/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6714 - val_loss: 0.6032 - val_accuracy: 0.6712
# Epoch 81/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6713 - val_loss: 0.6031 - val_accuracy: 0.6712
# Epoch 82/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6713 - val_loss: 0.6032 - val_accuracy: 0.6710
# Epoch 83/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6712 - val_loss: 0.6031 - val_accuracy: 0.6711
# Epoch 84/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6714 - val_loss: 0.6031 - val_accuracy: 0.6710
# Epoch 85/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6031 - val_accuracy: 0.6710
# Epoch 86/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6713 - val_loss: 0.6030 - val_accuracy: 0.6710
# Epoch 87/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6713 - val_loss: 0.6030 - val_accuracy: 0.6710
# Epoch 88/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6713 - val_loss: 0.6031 - val_accuracy: 0.6709
# Epoch 89/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6713 - val_loss: 0.6032 - val_accuracy: 0.6709
# Epoch 90/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6031 - val_accuracy: 0.6711
# Epoch 91/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6031 - val_accuracy: 0.6710
# Epoch 92/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6031 - val_accuracy: 0.6709
# Epoch 93/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6031 - val_accuracy: 0.6710
# Epoch 94/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6713 - val_loss: 0.6030 - val_accuracy: 0.6711
# Epoch 95/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6031 - val_accuracy: 0.6710
# Epoch 96/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6713 - val_loss: 0.6031 - val_accuracy: 0.6711
# Epoch 97/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6030 - val_accuracy: 0.6711
# Epoch 98/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6030 - val_accuracy: 0.6711
# Epoch 99/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6029 - val_accuracy: 0.6712
# Epoch 100/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6029 - val_accuracy: 0.6711
# Epoch 101/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6715 - val_loss: 0.6030 - val_accuracy: 0.6710
# Epoch 102/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6716 - val_loss: 0.6030 - val_accuracy: 0.6708
# Epoch 103/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6716 - val_loss: 0.6029 - val_accuracy: 0.6710
# Epoch 104/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6714 - val_loss: 0.6030 - val_accuracy: 0.6710
# Epoch 105/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6029 - val_accuracy: 0.6711
# Epoch 106/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6715 - val_loss: 0.6029 - val_accuracy: 0.6709
# Epoch 107/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6714 - val_loss: 0.6029 - val_accuracy: 0.6712
# Epoch 108/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6029 - val_accuracy: 0.6712
# Epoch 109/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6716 - val_loss: 0.6029 - val_accuracy: 0.6711
# Epoch 110/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6716 - val_loss: 0.6029 - val_accuracy: 0.6710
# Epoch 111/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6029 - val_accuracy: 0.6711
# Epoch 112/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6716 - val_loss: 0.6029 - val_accuracy: 0.6709
# Epoch 113/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6029 - val_accuracy: 0.6711
# Epoch 114/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6715 - val_loss: 0.6029 - val_accuracy: 0.6710
# Epoch 115/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6029 - val_accuracy: 0.6711
# Epoch 116/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6029 - val_accuracy: 0.6709
# Epoch 117/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6716 - val_loss: 0.6029 - val_accuracy: 0.6711
# Epoch 118/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6715 - val_loss: 0.6029 - val_accuracy: 0.6710
# Epoch 119/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6029 - val_accuracy: 0.6711
# Epoch 120/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6029 - val_accuracy: 0.6711
# Epoch 121/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 122/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 123/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6717 - val_loss: 0.6029 - val_accuracy: 0.6712
# Epoch 124/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 125/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 126/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 127/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 128/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 129/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6712
# Epoch 130/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6712
# Epoch 131/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 132/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 133/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 134/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6717 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 135/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6023 - accuracy: 0.6717 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 136/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 137/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 138/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6712
# Epoch 139/200
# 3137983/3137983 [==============================] - 4s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6712
# Epoch 140/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 141/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 142/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6712
# Epoch 143/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 144/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 145/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 146/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 147/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 148/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6717 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 149/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6712
# Epoch 150/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 151/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6717 - val_loss: 0.6028 - val_accuracy: 0.6711
# Epoch 152/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 153/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 154/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 155/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 156/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 157/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 158/200
# 3137983/3137983 [==============================] - 3s 1us/sample - loss: 0.6022 - accuracy: 0.6716 - val_loss: 0.6028 - val_accuracy: 0.6710
# Epoch 00158: early stopping
# Train on 3030268 samples, validate on 757568 samples
# Epoch 1/200
# 3030268/3030268 [==============================] - 10s 3us/sample - loss: 0.6218 - accuracy: 0.6595 - val_loss: 0.6129 - val_accuracy: 0.6652
# Epoch 2/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6114 - accuracy: 0.6658 - val_loss: 0.6086 - val_accuracy: 0.6681
# Epoch 3/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6097 - accuracy: 0.6666 - val_loss: 0.6084 - val_accuracy: 0.6689
# Epoch 4/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6088 - accuracy: 0.6673 - val_loss: 0.6075 - val_accuracy: 0.6695
# Epoch 5/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6086 - accuracy: 0.6672 - val_loss: 0.6092 - val_accuracy: 0.6681
# Epoch 6/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6078 - accuracy: 0.6678 - val_loss: 0.6089 - val_accuracy: 0.6675
# Epoch 7/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6076 - accuracy: 0.6679 - val_loss: 0.6067 - val_accuracy: 0.6694
# Epoch 8/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6073 - accuracy: 0.6682 - val_loss: 0.6069 - val_accuracy: 0.6689
# Epoch 9/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6070 - accuracy: 0.6683 - val_loss: 0.6064 - val_accuracy: 0.6698
# Epoch 10/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6066 - accuracy: 0.6689 - val_loss: 0.6058 - val_accuracy: 0.6703
# Epoch 11/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6066 - accuracy: 0.6686 - val_loss: 0.6063 - val_accuracy: 0.6697
# Epoch 12/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6066 - accuracy: 0.6687 - val_loss: 0.6062 - val_accuracy: 0.6700
# Epoch 13/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6063 - accuracy: 0.6690 - val_loss: 0.6062 - val_accuracy: 0.6696
# Epoch 14/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6062 - accuracy: 0.6689 - val_loss: 0.6058 - val_accuracy: 0.6702
# Epoch 15/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6062 - accuracy: 0.6688 - val_loss: 0.6050 - val_accuracy: 0.6705
# Epoch 16/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6061 - accuracy: 0.6689 - val_loss: 0.6059 - val_accuracy: 0.6697
# Epoch 17/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6057 - accuracy: 0.6691 - val_loss: 0.6053 - val_accuracy: 0.6704
# Epoch 18/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6056 - accuracy: 0.6694 - val_loss: 0.6049 - val_accuracy: 0.6708
# Epoch 19/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6055 - accuracy: 0.6695 - val_loss: 0.6049 - val_accuracy: 0.6703
# Epoch 20/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6055 - accuracy: 0.6693 - val_loss: 0.6052 - val_accuracy: 0.6704
# Epoch 21/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6053 - accuracy: 0.6697 - val_loss: 0.6047 - val_accuracy: 0.6708
# Epoch 22/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6053 - accuracy: 0.6695 - val_loss: 0.6051 - val_accuracy: 0.6701
# Epoch 23/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6052 - accuracy: 0.6696 - val_loss: 0.6057 - val_accuracy: 0.6699
# Epoch 24/200
# 3030268/3030268 [==============================] - 2s 1us/sample - loss: 0.6052 - accuracy: 0.6696 - val_loss: 0.6050 - val_accuracy: 0.6704
# Epoch 25/200
# 3030268/3030268 [==============================] - 2s 1us/sample - loss: 0.6050 - accuracy: 0.6698 - val_loss: 0.6048 - val_accuracy: 0.6708
# Epoch 26/200
# 3030268/3030268 [==============================] - 2s 1us/sample - loss: 0.6065 - accuracy: 0.6684 - val_loss: 0.6059 - val_accuracy: 0.6694
# Epoch 27/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6066 - accuracy: 0.6684 - val_loss: 0.6066 - val_accuracy: 0.6689
# Epoch 28/200
# 3030268/3030268 [==============================] - 2s 1us/sample - loss: 0.6060 - accuracy: 0.6689 - val_loss: 0.6053 - val_accuracy: 0.6703
# Epoch 29/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6062 - accuracy: 0.6688 - val_loss: 0.6065 - val_accuracy: 0.6690
# Epoch 30/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6063 - accuracy: 0.6688 - val_loss: 0.6084 - val_accuracy: 0.6663
# Epoch 31/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6062 - accuracy: 0.6688 - val_loss: 0.6050 - val_accuracy: 0.6706
# Epoch 32/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6058 - accuracy: 0.6691 - val_loss: 0.6066 - val_accuracy: 0.6690
# Epoch 33/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6058 - accuracy: 0.6691 - val_loss: 0.6051 - val_accuracy: 0.6703
# Epoch 34/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6056 - accuracy: 0.6693 - val_loss: 0.6047 - val_accuracy: 0.6704
# Epoch 35/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6055 - accuracy: 0.6693 - val_loss: 0.6050 - val_accuracy: 0.6707
# Epoch 36/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6057 - accuracy: 0.6691 - val_loss: 0.6069 - val_accuracy: 0.6686
# Epoch 37/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6056 - accuracy: 0.6692 - val_loss: 0.6048 - val_accuracy: 0.6704
# Epoch 38/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6054 - accuracy: 0.6693 - val_loss: 0.6049 - val_accuracy: 0.6703
# Epoch 39/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6057 - accuracy: 0.6691 - val_loss: 0.6057 - val_accuracy: 0.6698
# Epoch 40/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6054 - accuracy: 0.6692 - val_loss: 0.6048 - val_accuracy: 0.6704
# Epoch 41/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6055 - accuracy: 0.6691 - val_loss: 0.6048 - val_accuracy: 0.6709
# Epoch 42/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6052 - accuracy: 0.6696 - val_loss: 0.6053 - val_accuracy: 0.6703
# Epoch 43/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6051 - accuracy: 0.6695 - val_loss: 0.6054 - val_accuracy: 0.6704
# Epoch 44/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6050 - accuracy: 0.6694 - val_loss: 0.6046 - val_accuracy: 0.6707
# Epoch 45/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6050 - accuracy: 0.6695 - val_loss: 0.6058 - val_accuracy: 0.6694
# Epoch 46/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6048 - accuracy: 0.6698 - val_loss: 0.6040 - val_accuracy: 0.6711
# Epoch 47/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6049 - accuracy: 0.6697 - val_loss: 0.6044 - val_accuracy: 0.6708
# Epoch 48/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6047 - accuracy: 0.6699 - val_loss: 0.6042 - val_accuracy: 0.6710
# Epoch 49/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6046 - accuracy: 0.6700 - val_loss: 0.6039 - val_accuracy: 0.6708
# Epoch 50/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6047 - accuracy: 0.6699 - val_loss: 0.6040 - val_accuracy: 0.6711
# Epoch 51/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6039 - accuracy: 0.6706 - val_loss: 0.6034 - val_accuracy: 0.6716
# Epoch 52/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6038 - accuracy: 0.6705 - val_loss: 0.6038 - val_accuracy: 0.6712
# Epoch 53/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6038 - accuracy: 0.6704 - val_loss: 0.6036 - val_accuracy: 0.6711
# Epoch 54/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6036 - accuracy: 0.6707 - val_loss: 0.6032 - val_accuracy: 0.6716
# Epoch 55/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6036 - accuracy: 0.6707 - val_loss: 0.6033 - val_accuracy: 0.6717
# Epoch 56/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6036 - accuracy: 0.6707 - val_loss: 0.6031 - val_accuracy: 0.6716
# Epoch 57/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6035 - accuracy: 0.6707 - val_loss: 0.6032 - val_accuracy: 0.6717
# Epoch 58/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6036 - accuracy: 0.6706 - val_loss: 0.6031 - val_accuracy: 0.6715
# Epoch 59/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6035 - accuracy: 0.6708 - val_loss: 0.6032 - val_accuracy: 0.6715
# Epoch 60/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6034 - accuracy: 0.6708 - val_loss: 0.6030 - val_accuracy: 0.6718
# Epoch 61/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6034 - accuracy: 0.6709 - val_loss: 0.6030 - val_accuracy: 0.6717
# Epoch 62/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6034 - accuracy: 0.6709 - val_loss: 0.6031 - val_accuracy: 0.6715
# Epoch 63/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6033 - accuracy: 0.6708 - val_loss: 0.6035 - val_accuracy: 0.6713
# Epoch 64/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6033 - accuracy: 0.6709 - val_loss: 0.6029 - val_accuracy: 0.6719
# Epoch 65/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6033 - accuracy: 0.6709 - val_loss: 0.6033 - val_accuracy: 0.6716
# Epoch 66/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6032 - accuracy: 0.6709 - val_loss: 0.6028 - val_accuracy: 0.6718
# Epoch 67/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6032 - accuracy: 0.6710 - val_loss: 0.6029 - val_accuracy: 0.6716
# Epoch 68/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6032 - accuracy: 0.6710 - val_loss: 0.6029 - val_accuracy: 0.6719
# Epoch 69/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6031 - accuracy: 0.6710 - val_loss: 0.6029 - val_accuracy: 0.6718
# Epoch 70/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6031 - accuracy: 0.6710 - val_loss: 0.6028 - val_accuracy: 0.6719
# Epoch 71/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6031 - accuracy: 0.6710 - val_loss: 0.6028 - val_accuracy: 0.6718
# Epoch 72/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6710 - val_loss: 0.6028 - val_accuracy: 0.6716
# Epoch 73/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6711 - val_loss: 0.6029 - val_accuracy: 0.6716
# Epoch 74/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6031 - accuracy: 0.6711 - val_loss: 0.6029 - val_accuracy: 0.6718
# Epoch 75/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6711 - val_loss: 0.6027 - val_accuracy: 0.6720
# Epoch 76/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6712 - val_loss: 0.6027 - val_accuracy: 0.6720
# Epoch 77/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6711 - val_loss: 0.6027 - val_accuracy: 0.6719
# Epoch 78/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6029 - accuracy: 0.6711 - val_loss: 0.6027 - val_accuracy: 0.6720
# Epoch 79/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6029 - accuracy: 0.6712 - val_loss: 0.6026 - val_accuracy: 0.6719
# Epoch 80/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6030 - accuracy: 0.6710 - val_loss: 0.6027 - val_accuracy: 0.6720
# Epoch 81/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6029 - accuracy: 0.6711 - val_loss: 0.6026 - val_accuracy: 0.6719
# Epoch 82/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6712 - val_loss: 0.6026 - val_accuracy: 0.6721
# Epoch 83/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6029 - accuracy: 0.6712 - val_loss: 0.6026 - val_accuracy: 0.6721
# Epoch 84/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6712 - val_loss: 0.6028 - val_accuracy: 0.6718
# Epoch 85/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6713 - val_loss: 0.6027 - val_accuracy: 0.6717
# Epoch 86/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6713 - val_loss: 0.6026 - val_accuracy: 0.6719
# Epoch 87/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6712 - val_loss: 0.6025 - val_accuracy: 0.6720
# Epoch 88/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6712 - val_loss: 0.6026 - val_accuracy: 0.6719
# Epoch 89/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6028 - accuracy: 0.6712 - val_loss: 0.6026 - val_accuracy: 0.6719
# Epoch 90/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6713 - val_loss: 0.6025 - val_accuracy: 0.6721
# Epoch 91/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6713 - val_loss: 0.6027 - val_accuracy: 0.6719
# Epoch 92/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6713 - val_loss: 0.6025 - val_accuracy: 0.6720
# Epoch 93/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6714 - val_loss: 0.6025 - val_accuracy: 0.6719
# Epoch 94/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6713 - val_loss: 0.6026 - val_accuracy: 0.6720
# Epoch 95/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6027 - accuracy: 0.6713 - val_loss: 0.6026 - val_accuracy: 0.6719
# Epoch 96/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6713 - val_loss: 0.6025 - val_accuracy: 0.6720
# Epoch 97/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6713 - val_loss: 0.6025 - val_accuracy: 0.6720
# Epoch 98/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6025 - val_accuracy: 0.6720
# Epoch 99/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6025 - val_accuracy: 0.6720
# Epoch 100/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6713 - val_loss: 0.6024 - val_accuracy: 0.6720
# Epoch 101/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6025 - val_accuracy: 0.6721
# Epoch 102/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6025 - val_accuracy: 0.6719
# Epoch 103/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6713 - val_loss: 0.6025 - val_accuracy: 0.6721
# Epoch 104/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6713 - val_loss: 0.6025 - val_accuracy: 0.6719
# Epoch 105/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6025 - val_accuracy: 0.6719
# Epoch 106/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6713 - val_loss: 0.6025 - val_accuracy: 0.6720
# Epoch 107/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6026 - accuracy: 0.6714 - val_loss: 0.6025 - val_accuracy: 0.6721
# Epoch 108/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6719
# Epoch 109/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6715 - val_loss: 0.6025 - val_accuracy: 0.6720
# Epoch 110/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6025 - val_accuracy: 0.6720
# Epoch 111/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6024 - val_accuracy: 0.6719
# Epoch 112/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6025 - val_accuracy: 0.6719
# Epoch 113/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 114/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 115/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6024 - val_accuracy: 0.6719
# Epoch 116/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6024 - val_accuracy: 0.6720
# Epoch 117/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6024 - val_accuracy: 0.6718
# Epoch 118/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6024 - val_accuracy: 0.6720
# Epoch 119/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6025 - accuracy: 0.6714 - val_loss: 0.6024 - val_accuracy: 0.6719
# Epoch 120/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 121/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6720
# Epoch 122/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6721
# Epoch 123/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6721
# Epoch 124/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6719
# Epoch 125/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6720
# Epoch 126/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6719
# Epoch 127/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6722
# Epoch 128/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6025 - val_accuracy: 0.6719
# Epoch 129/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 130/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6720
# Epoch 131/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 132/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 133/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6721
# Epoch 134/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6721
# Epoch 135/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 136/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 137/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 138/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 139/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6721
# Epoch 140/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6721
# Epoch 141/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6721
# Epoch 142/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6716 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 143/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6714 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 144/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6716 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 145/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 146/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6719
# Epoch 147/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 148/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 149/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 150/200
# 3030268/3030268 [==============================] - 4s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 151/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6023 - val_accuracy: 0.6720
# Epoch 152/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 153/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 154/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 155/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 156/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 157/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 158/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 159/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 160/200
# 3030268/3030268 [==============================] - 3s 1us/sample - loss: 0.6024 - accuracy: 0.6715 - val_loss: 0.6024 - val_accuracy: 0.6721
# Epoch 00160: early stopping
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd.h5
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even.h5

# %%
model_odd = Load_Model(path_tosave, name="_odd")
model_even = Load_Model(path_tosave, name="_even")
# Out:
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd.h5)
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even.h5)

# %%
Predicted_even = model_odd.predict(even[0])
Predicted_odd = model_even.predict(odd[0])

# %%
pred = np.concatenate([Predicted_even, Predicted_odd])
truth = np.concatenate([even[1], odd[1]])

fpr, tpr, thr = roc_curve(truth, pred)
roc_auc = auc(fpr, tpr)

fpr_even, tpr_even, thr_even = roc_curve(even[1], Predicted_even)
roc_auc_even = auc(fpr_even, tpr_even)

fpr_odd, tpr_odd, thr_odd = roc_curve(odd[1], Predicted_odd)
roc_auc_odd = auc(fpr_odd, tpr_odd)

fig = plt.figure()
plt.plot(fpr_even, tpr_even, linestyle='--', label='Even ROC curve (area = {:.4f})'.format(roc_auc_even))
plt.plot(fpr_odd, tpr_odd, linestyle='--', color='teal', label='Odd: ROC curve (area = {:.4f})'.format(roc_auc_odd))
plt.plot(fpr, tpr, color='darkorange', label='Combined: ROC curve (area = {:.4f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig(path_SvsS + "ROC-Curve.png")
plt.show()

# %%
def Find_Eff_Cut_Equal(Sig, Bkg):
    steps = 1000
    Cut = np.linspace(0,1,steps)
    Sig_Eff_list = []
    Bkg_Eff_list = []
    for i in range(steps):    
        Sig_Eff_list.append(Sig[Sig > Cut[i]].size/Sig.size)
        Bkg_Eff_list.append(Bkg[Bkg < Cut[i]].size/Bkg.size)
    Sig_Eff_list = np.array(Sig_Eff_list)
    Bkg_Eff_list = np.array(Bkg_Eff_list)
    best_step = np.argmax(Sig_Eff_list + Bkg_Eff_list - (abs(Sig_Eff_list - Bkg_Eff_list)/2 ) )
    
    print(f"Cut_Value: {Cut[best_step]:.3f}")
    print(f"Sig_Eff: {Sig_Eff_list[best_step]:.3f}")
    print(f"Bkg_Eff: {Bkg_Eff_list[best_step]:.3f}")
    
    return Sig_Eff_list[best_step], Bkg_Eff_list[best_step], Cut[best_step]

Sig = pred[truth==1]
Bkg = pred[truth==0]
Sig_Eff, Bkg_Eff, Signal_Cut = Find_Eff_Cut_Equal(Sig=Sig, Bkg=Bkg)
# Out:
# Cut_Value: 0.539
# Sig_Eff: 0.669
# Bkg_Eff: 0.668

# %%
fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output Cuu/Cqu", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Density")
histargs = {"bins":40, "range":(0,1.), "density":True, "histtype":'step'}
plt.hist(pred[truth==1],label = "Cqu", **histargs)
plt.hist(pred[truth==0],label = "Cuu", **histargs)
plt.vlines(Signal_Cut, ymin=plt.gca().get_ylim()[0]+ plt.gca().get_ylim()[1]*0.02, ymax=plt.gca().get_ylim()[1]*0.98, color='red', linestyle='--', label='Cut-Value', alpha=0.8, linewidth=1.3)
plt.legend(loc='upper left', frameon=False,)
plt.savefig(path_SvsS + "DNN-Output-Signal.png")
plt.show()
#saveit = "{}/{}".format(path_tosave, "DNN_Output.png")
#plt.savefig(saveit)

# %%
from sklearn import metrics
pred = np.squeeze(pred)
pred_cut = np.zeros([pred.size])
pred_cut[pred > Signal_Cut] = 1
pred_cut[pred < Signal_Cut] = 0
confusion_matrix = np.round(metrics.confusion_matrix(truth, pred_cut, normalize='true'), 4)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.savefig(path_SvsS + "Confusion_Matrix.png")
plt.show()

print(confusion_matrix)
# Out:
# [[0.6683 0.3317]
#  [0.3312 0.6688]]

# %%
#f, g = get_feature_importance(even, model_odd, Signal_Cut, 2)
#idx = np.argsort(f)
#fig, ax = plt.subplots(figsize=(20, 10))
#ax.barh(range(even[0].shape[1]), np.sort(f), color="r", alpha=0.7)
#ax.set_yticks(range(even[0].shape[1]), np.array(feature_names)[idx])
#ax.set_xlabel('Feature Importance')
#plt.savefig(path_SvsS + "/Feature_Importance_even.png")

# %% [markdown]
# # Test on Background

# %%
samples, feature_names, class_names, class_no = load_input_file('data/V05_sstt_Data.h5', features_to_ignore)
input_features, targets, class_labels, weights = build_combined_input(samples)
# Out:
# Found 21 features on the dataset 21 features were loaded:
#
# DEtall_SS
# DPhill_SS
# DRll01
# HT_jets
# HT_lep
# Mll01
# MtLepMet
# jet_pseudoscore_DL1r0
# jet_pseudoscore_DL1r1
# jet_pseudoscore_DL1r2
# DeltaR_max_lep_bjet77
# DeltaR_min_lep_bjet77
# DRjj_lead
# jet_pt0_nofwd
# met_met
# total_charge
# nJets_OR
# nJets_OR_DL1r_77
# sumPsbtag
# sumPsbtag77
# randomRunNumber
#
# Dataset contains extra labels for different backgrounds!
# Class 0  :  253953
# Class 1  :  231587
# Class 2  :  3249
# Class 3  :  310859
# Class 4  :  190589
# Class 5  :  223033
# Class 6  :  355647
# Class 7  :  109991
# Class 8  :  1039
# Class 9  :  0
# Class 10  :  425286
# Dataset contains 679239 Signal events and 1425994 Background events.

# %%
#Extract and drop RunNumber
feature_names = feature_names[:-1]
run_numbers = input_features[:,-1]
input_features = input_features[:,:-1]

# %%
input_scaled = scaler.transform(input_features)
odd, even = Fold_Odd_Even(input_scaled, targets, weights, class_labels, run_numbers)

# %%
Pred_odd = model_even.predict(odd[0])
Pred_even = model_odd.predict(even[0])

Pred = np.concatenate([Pred_odd, Pred_even])
Truth = np.concatenate([odd[1], even[1]])
Weights = np.concatenate([odd[2], even[2]])
Class_labels = np.concatenate([odd[3], even[3]])

# %%
fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output Cuu/Cqu", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Density")
histargs = {"bins":40, "range":(0,1.), "density":True, "histtype":'step'}
plt.hist(Pred[Truth==0], label = "Background", **histargs)
plt.hist(Pred[Truth==1], label="Signal", **histargs)
plt.vlines(Signal_Cut, ymin=plt.gca().get_ylim()[0]+ plt.gca().get_ylim()[1]*0.02, ymax=plt.gca().get_ylim()[1]*0.98, color='red', linestyle='--', label='Cut-Value', alpha=0.8, linewidth=1.3)
plt.legend(frameon=False, loc='upper left')
plt.savefig(path_SvsS + "DNN-Output-Signal-Background.png")
plt.show()

# %%
index_sort = np.argsort(class_no)
class_names = (np.array(class_names)[index_sort])
class_no = np.sort(class_no)

# %%
fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output Cuu/Cqu", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events")
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
for i in range(1,9):
    plt.hist(Pred[Class_labels == i], label = class_names[i], **histargs)
plt.vlines(Signal_Cut, ymin=plt.gca().get_ylim()[0]+ plt.gca().get_ylim()[1]*0.02, ymax=plt.gca().get_ylim()[1]*0.98, color='red', linestyle='--', label='Cut-Value', alpha=0.8, linewidth=1.3)
plt.savefig(path_SvsS + "DNN-Output-Background-classes.png")
plt.legend(frameon=False, loc='upper left')
plt.show()

# %%
fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output Cuu/Cqu", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events weighted")
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
for i in range(1,9):
    plt.hist(Pred[Class_labels == i], label = class_names[i], **histargs, weights=Weights[Class_labels == i])
plt.vlines(Signal_Cut, ymin=plt.gca().get_ylim()[0]+ plt.gca().get_ylim()[1]*0.02, ymax=plt.gca().get_ylim()[1]*0.98, color='red', linestyle='--', label='Cut-Value', alpha=0.8, linewidth=1.3)
plt.legend(frameon=False, loc='upper left')
plt.savefig(path_SvsS + "DNN-Output-Background-classes_weighted.png")
plt.show()

# %% [markdown]
# # Split into Cuu SR & Cqu SR

# %%
def Split_in_SR(input_data, Predict, Signal_Cut):
    mask_cuu = np.squeeze(Predict < Signal_Cut)
    mask_cqu = np.squeeze(Predict >= Signal_Cut)
    features_cuu = input_data[0][mask_cuu,:]
    features_cqu = input_data[0][mask_cqu,:]
    targets_cuu = input_data[1][mask_cuu]
    targets_cqu = input_data[1][mask_cqu]
    weights_cuu = input_data[2][mask_cuu]
    weights_cqu = input_data[2][mask_cqu]
    class_labels_cuu = input_data[3][mask_cuu]
    class_labels_cqu = input_data[3][mask_cqu]
    cuu = (features_cuu, targets_cuu, weights_cuu, class_labels_cuu)
    cqu = (features_cqu, targets_cqu, weights_cqu, class_labels_cqu)
    return cuu, cqu

# %%
odd_cuu, odd_cqu = Split_in_SR(odd, Pred_odd, Signal_Cut=Signal_Cut)
even_cuu, even_cqu = Split_in_SR(even, Pred_even, Signal_Cut=Signal_Cut)

# %%
# Reduce to 6 features for Signal over Background NN
Wanted_Features = ['jet_pseudoscore_DL1r0', 'jet_pseudoscore_DL1r1', 'HT_lep', 'MtLepMet', 'jet_pt0_nofwd', 'nJets_OR', 'total_charge']
i = 0
Wanted_Features_idx_list = []
for feature in feature_names:
    for Wanted_Feature in Wanted_Features:    
        if feature == Wanted_Feature:
            Wanted_Features_idx_list.append(i)
    i += 1

# %%
def Recombine_reduced_data(input_data, input_features):
    return (input_features, input_data[1], input_data[2], input_data[3])

def Reduce_Features(input_data, feature_list, feature_names):
    features_to_delete = []
    if input_data[0].shape[1] == 6:
        print("Exit function, data is already reduced!")
        return input_data
    for i in range(input_data[0].shape[1]):
        if i not in feature_list:
            features_to_delete.append(i)
            
    features_to_delete.reverse()
    input_features = input_data[0]
    
    for feature_idx in features_to_delete:
        input_features = np.delete(input_features, feature_idx, 1)
        
    input_data = Recombine_reduced_data(input_data, input_features)
    
    return input_data

# %%
odd_cuu = Reduce_Features(odd_cuu, Wanted_Features_idx_list, feature_names)
even_cuu = Reduce_Features(even_cuu, Wanted_Features_idx_list, feature_names)
odd_cqu = Reduce_Features(odd_cqu, Wanted_Features_idx_list, feature_names)
even_cqu = Reduce_Features(even_cqu, Wanted_Features_idx_list, feature_names)
if len(feature_names) > len(Wanted_Features):
    feature_names = np.array(feature_names)[Wanted_Features_idx_list].tolist()

# %% [markdown]
# # Charge Split

# %%
# Find total_charge index
i = 0
for feature in feature_names:
    if feature == 'total_charge':
        total_charge_idx = i
    i += 1
print("Found", feature_names[total_charge_idx], "at index", total_charge_idx)
# Out:
# Found total_charge at index 5

# %%
def Split_by_Charge(input_data):
    input_scaled = input_data[0]
    
    # Multiply by one to counter flip which occurs due to scaling
    total_charge = input_scaled[:,total_charge_idx] * -1
    input_scaled = np.delete(input_scaled, total_charge_idx, 1)
    
    # ++
    input_scaled_pos = input_scaled[total_charge > 0]
    targets_pos = input_data[1][total_charge > 0]
    weights_pos = input_data[2][total_charge > 0]
    class_labels_pos = input_data[3][total_charge > 0]
    # --
    input_scaled_neg = input_scaled[total_charge < 0]
    targets_neg = input_data[1][total_charge < 0]
    weights_neg = input_data[2][total_charge < 0]
    class_labels_neg = input_data[3][total_charge < 0]
    
    return (input_scaled_pos, targets_pos, weights_pos, class_labels_pos), (input_scaled_neg, targets_neg, weights_neg, class_labels_neg)

# %%
odd_cuu_pos, odd_cuu_neg = Split_by_Charge(odd_cuu)
odd_cqu_pos, odd_cqu_neg = Split_by_Charge(odd_cqu)
even_cuu_pos, even_cuu_neg = Split_by_Charge(even_cuu)
even_cqu_pos, even_cqu_neg = Split_by_Charge(even_cqu)

# %%
ScaleWeights(odd_cuu_pos[1],odd_cuu_pos[2])
ScaleWeights(even_cuu_pos[1],even_cuu_pos[2])
ScaleWeights(odd_cqu_pos[1],odd_cqu_pos[2])
ScaleWeights(even_cqu_pos[1],even_cqu_pos[2])
ScaleWeights(odd_cuu_neg[1],odd_cuu_neg[2])
ScaleWeights(even_cuu_neg[1],even_cuu_neg[2])
ScaleWeights(odd_cqu_neg[1],odd_cqu_neg[2])
ScaleWeights(even_cqu_neg[1],even_cqu_neg[2])
# Out:
# ======Weight Statistic========================================
# Weights::        W(1)=254.279, W(0)=159.126
# Scaled weights:: W(1)=65078.5, W(0)=65078.5
# ==============================================================
#
# ======Weight Statistic========================================
# Weights::        W(1)=256.359, W(0)=181.255
# Scaled weights:: W(1)=67873.5, W(0)=67873.5
# ==============================================================
#
# ======Weight Statistic========================================
# Weights::        W(1)=327.8, W(0)=693.974
# Scaled weights:: W(1)=207379, W(0)=207379
# ==============================================================
#
# ======Weight Statistic========================================
# Weights::        W(1)=314.217, W(0)=675.393
# Scaled weights:: W(1)=194899, W(0)=194899
# ==============================================================
#
# ======Weight Statistic========================================
# Weights::        W(1)=13.4949, W(0)=180.089
# Scaled weights:: W(1)=101333, W(0)=101333
# ==============================================================
#
# ======Weight Statistic========================================
# Weights::        W(1)=13.5005, W(0)=187.905
# Scaled weights:: W(1)=102440, W(0)=102440
# ==============================================================
#
# ======Weight Statistic========================================
# Weights::        W(1)=10.5857, W(0)=467.859
# Scaled weights:: W(1)=161987, W(0)=161987
# ==============================================================
#
# ======Weight Statistic========================================
# Weights::        W(1)=10.2407, W(0)=438.087
# Scaled weights:: W(1)=151626, W(0)=151626
# ==============================================================

# %% [markdown]
# # Train SvsB NN

# %%
hist_cuu_odd_pos, model_cuu_odd_pos, hist_cuu_even_pos, model_cuu_even_pos = Train_Odd_Even(odd_cuu_pos, even_cuu_pos, n_epochs = n_epochs, batch_size = batch_size)
history_list_cuu_pos = [hist_cuu_odd_pos, hist_cuu_even_pos]
Plot_Metrics_KFold(history_list_cuu_pos, path_SvsB, "Pos_Cuu_Models_")

hist_cqu_odd_pos, model_cqu_odd_pos, hist_cqu_even_pos, model_cqu_even_pos = Train_Odd_Even(odd_cqu_pos, even_cqu_pos, n_epochs = n_epochs, batch_size = batch_size)
history_list_cqu_pos = [hist_cqu_odd_pos, hist_cqu_even_pos]
Plot_Metrics_KFold(history_list_cqu_pos, path_SvsB, "Pos_Cqu_Models_")

Save_Model(model_cuu_odd_pos, path_tosave, "_odd_cuu_pos")
Save_Model(model_cuu_even_pos, path_tosave, "_even_cuu_pos")
Save_Model(model_cqu_odd_pos, path_tosave, "_odd_cqu_pos")
Save_Model(model_cqu_even_pos, path_tosave, "_even_cqu_pos")
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_19 (Dense)             (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# /home/avdgraaf/.local/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00143: early stopping
# Epoch 00153: early stopping
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_23 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_24 (Dense)             (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_26 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_27 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_28 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_29 (Dense)             (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 00151: early stopping
# Epoch 00154: early stopping
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd_cuu_pos.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd_cuu_pos.h5
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even_cuu_pos.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even_cuu_pos.h5
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd_cqu_pos.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd_cqu_pos.h5
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even_cqu_pos.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even_cqu_pos.h5

# %%
n_epochs = 125
hist_cuu_odd_neg, model_cuu_odd_neg, hist_cuu_even_neg, model_cuu_even_neg = Train_Odd_Even(odd_cuu_neg, even_cuu_neg, n_epochs = n_epochs, batch_size = batch_size)
history_list_cuu_neg = [hist_cuu_odd_neg, hist_cuu_even_neg]
Plot_Metrics_KFold(history_list_cuu_neg, path_SvsB, "Neg_Cuu_Models_")

hist_cqu_odd_neg, model_cqu_odd_neg, hist_cqu_even_neg, model_cqu_even_neg = Train_Odd_Even(odd_cqu_neg, even_cqu_neg, n_epochs = n_epochs, batch_size = batch_size)
history_list_cqu_neg = [hist_cqu_odd_neg, hist_cqu_even_neg]
Plot_Metrics_KFold(history_list_cqu_neg, path_SvsB, "Neg_Cqu_Models_")

Save_Model(model_cuu_odd_neg, path_tosave, "_odd_cuu_neg")
Save_Model(model_cuu_even_neg, path_tosave, "_even_cuu_neg")
Save_Model(model_cqu_odd_neg, path_tosave, "_odd_cqu_neg")
Save_Model(model_cqu_even_neg, path_tosave, "_even_cqu_neg")
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_32 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_33 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_34 (Dense)             (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_36 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_37 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_38 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_39 (Dense)             (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_41 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_42 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_43 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_44 (Dense)             (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 6)]               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_46 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_47 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_48 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_49 (Dense)             (None, 8)                 136
# _________________________________________________________________
# OutputLayer (Dense)          (None, 1)                 9
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd_cuu_neg.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd_cuu_neg.h5
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even_cuu_neg.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even_cuu_neg.h5
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd_cqu_neg.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd_cqu_neg.h5
# Saving architecture to: /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even_cqu_neg.json
# Saving weights to     : /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even_cqu_neg.h5

# %% [markdown]
# # Evaluate

# %%
model_cuu_even_pos = Load_Model(path_tosave, name="_even_cuu_pos")
model_cuu_odd_pos = Load_Model(path_tosave, name="_odd_cuu_pos")
model_cqu_even_pos = Load_Model(path_tosave, name="_even_cqu_pos")
model_cqu_odd_pos = Load_Model(path_tosave, name="_odd_cqu_pos")
model_cuu_even_neg = Load_Model(path_tosave, name="_even_cuu_neg")
model_cuu_odd_neg = Load_Model(path_tosave, name="_odd_cuu_neg")
model_cqu_even_neg = Load_Model(path_tosave, name="_even_cqu_neg")
model_cqu_odd_neg = Load_Model(path_tosave, name="_odd_cqu_neg")
# Out:
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even_cuu_pos.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even_cuu_pos.h5)
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd_cuu_pos.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd_cuu_pos.h5)
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even_cqu_pos.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even_cqu_pos.h5)
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd_cqu_pos.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd_cqu_pos.h5)
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even_cuu_neg.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even_cuu_neg.h5)
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd_cuu_neg.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd_cuu_neg.h5)
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_even_cqu_neg.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_even_cqu_neg.h5)
# Loading model architecture and weights (/mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/architecture_odd_cqu_neg.json, /mnt/c/Users/aaron/Desktop/PhD/Same_Sign_Top/NN_for_sstt/NN/Models/V05_SvsS_Final_6Vars/weights_odd_cqu_neg.h5)

# %%
#Reload Data to have non scaled weights
odd_cuu_pos, odd_cuu_neg = Split_by_Charge(odd_cuu)
odd_cqu_pos, odd_cqu_neg = Split_by_Charge(odd_cqu)
even_cuu_pos, even_cuu_neg = Split_by_Charge(even_cuu)
even_cqu_pos, even_cqu_neg = Split_by_Charge(even_cqu)

# %%
pred1 = model_cuu_odd_pos.predict(even_cuu_pos[0])
pred2 = model_cuu_even_pos.predict(odd_cuu_pos[0])
pred3 = model_cqu_odd_pos.predict(even_cqu_pos[0])
pred4 = model_cqu_even_pos.predict(odd_cqu_pos[0])
pred5 = model_cuu_odd_neg.predict(even_cuu_neg[0])
pred6 = model_cuu_even_neg.predict(odd_cuu_neg[0])
pred7 = model_cqu_odd_neg.predict(even_cqu_neg[0])
pred8 = model_cqu_even_neg.predict(odd_cqu_neg[0])

truth1 = even_cuu_pos[1]
truth2 = odd_cuu_pos[1]
truth3 = even_cqu_pos[1]
truth4 = odd_cqu_pos[1]
truth5 = even_cuu_neg[1]
truth6 = odd_cuu_neg[1]
truth7 = even_cqu_neg[1]
truth8 = odd_cqu_neg[1]

weights1 = even_cuu_pos[2]
weights2 = odd_cuu_pos[2]
weights3 = even_cqu_pos[2]
weights4 = odd_cqu_pos[2]
weights5 = even_cuu_neg[2]
weights6 = odd_cuu_neg[2]
weights7 = even_cqu_neg[2]
weights8 = odd_cqu_neg[2]

# %%
pred_cuu_pos = np.concatenate([pred1, pred2])
truth_cuu_pos = np.concatenate([truth1, truth2])
weights_cuu_pos = np.concatenate([weights1, weights2])

pred_cqu_pos = np.concatenate([pred3, pred4])
truth_cqu_pos = np.concatenate([truth3, truth4])
weights_cqu_pos = np.concatenate([weights3, weights4])

pred_cuu_neg = np.concatenate([pred5, pred6])
truth_cuu_neg = np.concatenate([truth5, truth6])
weights_cuu_neg = np.concatenate([weights5, weights6])

pred_cqu_neg = np.concatenate([pred7, pred8])
truth_cqu_neg = np.concatenate([truth7, truth8])
weights_cqu_neg = np.concatenate([weights7, weights8])

# %%
fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events weighted")
#plt.yscale('log')
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
plt.hist(pred_cuu_pos[:,0][truth_cuu_pos==1],label = "++ cuu Signal", **histargs, weights=weights_cuu_pos[truth_cuu_pos==1])
plt.hist(pred_cuu_pos[:,0][truth_cuu_pos==0],label = "++ cuu Background", **histargs, weights=weights_cuu_pos[truth_cuu_pos==0])
plt.legend(loc='upper center', frameon=False)
plt.savefig(path_SvsB + "Pos_Cuu_DNN-Output_Weighted.png")
plt.show()

fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events weighted")
#plt.yscale('log')
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
plt.hist(pred_cuu_neg[:,0][truth_cuu_neg==1],label = "-- cuu Signal", **histargs, weights=weights_cuu_neg[truth_cuu_neg==1])
plt.hist(pred_cuu_neg[:,0][truth_cuu_neg==0],label = "-- cuu Background", **histargs, weights=weights_cuu_neg[truth_cuu_neg==0])
plt.legend(loc='upper center', frameon=False)
plt.savefig(path_SvsB + "Neg_Cuu_DNN-Output_Weighted.png")
plt.show()

fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events weighted")
#plt.yscale('log')
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
plt.hist(pred_cqu_pos[:,0][truth_cqu_pos==1],label = "++ cqu Signal", **histargs, weights=weights_cqu_pos[truth_cqu_pos==1])
plt.hist(pred_cqu_pos[:,0][truth_cqu_pos==0],label = "++ cqu Background", **histargs, weights=weights_cqu_pos[truth_cqu_pos==0])
plt.legend(loc='upper center', frameon=False)
plt.savefig(path_SvsB + "Pos_Cqu_DNN-Output_Weighted.png")
plt.show()

fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events weighted")
#plt.yscale('log')
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
plt.hist(pred_cqu_neg[:,0][truth_cqu_neg==1],label = "-- cqu Signal", **histargs, weights=weights_cqu_neg[truth_cqu_neg==1])
plt.hist(pred_cqu_neg[:,0][truth_cqu_neg==0],label = "-- cqu Background", **histargs, weights=weights_cqu_neg[truth_cqu_neg==0])
plt.legend(loc='upper center', frameon=False)
plt.savefig(path_SvsB + "Neg_Cqu_DNN-Output_Weighted.png")
plt.show()

fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events")
#plt.yscale('log')
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
plt.hist(pred_cuu_pos[:,0][truth_cuu_pos==1],label = "++ cuu Signal", **histargs)
plt.hist(pred_cuu_pos[:,0][truth_cuu_pos==0],label = "++ cuu Background", **histargs)
plt.legend(loc='upper center', frameon=False)
plt.tight_layout()
plt.savefig(path_SvsB + "Pos_Cuu_DNN-Output.png")
plt.show()

fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events")
#plt.yscale('log')
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
plt.hist(pred_cuu_neg[:,0][truth_cuu_neg==1],label = "-- cuu Signal", **histargs)
plt.hist(pred_cuu_neg[:,0][truth_cuu_neg==0],label = "-- cuu Background", **histargs)
plt.legend(loc='upper center', frameon=False)
plt.tight_layout()
plt.savefig(path_SvsB + "neg_Cuu_DNN-Output.png")
plt.show()

fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events")
#plt.yscale('log')
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
plt.hist(pred_cqu_pos[:,0][truth_cqu_pos==1],label = "++ cqu Signal", **histargs)
plt.hist(pred_cqu_pos[:,0][truth_cqu_pos==0],label = "++ cqu Background", **histargs)
plt.legend(loc='upper center', frameon=False)
plt.tight_layout()
plt.savefig(path_SvsB + "Pos_Cqu_DNN-Output.png")
plt.show()

fig = plt.figure()
plt.grid(color='k', which='both', linestyle='--', lw=0.5, alpha=0.1, zorder = 0)
plt.xlabel("NN output", horizontalalignment='right', x=1)
plt.xlim([0,1])
plt.ylabel("Number of events")
#plt.yscale('log')
histargs = {"bins":40, "range":(0,1.), "histtype":'step'}
plt.hist(pred_cqu_neg[:,0][truth_cqu_neg==1],label = "-- cqu Signal", **histargs)
plt.hist(pred_cqu_neg[:,0][truth_cqu_neg==0],label = "-- cqu Background", **histargs)
plt.legend(loc='upper center', frameon=False)
plt.tight_layout()
plt.savefig(path_SvsB + "Neg_Cqu_DNN-Output.png")
plt.show()

# %%
fpr1, tpr1, thr1 = roc_curve(truth_cuu_pos, pred_cuu_pos, sample_weight=weights_cuu_pos)
fpr2, tpr2, thr2 = roc_curve(truth_cuu_neg, pred_cuu_neg, sample_weight=weights_cuu_neg)
fpr3, tpr3, thr3 = roc_curve(truth_cqu_pos, pred_cqu_pos, sample_weight=weights_cqu_pos)
fpr4, tpr4, thr4 = roc_curve(truth_cqu_neg, pred_cqu_neg, sample_weight=weights_cqu_neg)

roc_auc1 = auc(fpr1, tpr1)
roc_auc2 = auc(fpr2, tpr2)
roc_auc3 = auc(fpr3, tpr3)
roc_auc4 = auc(fpr4, tpr4)

# %%
plt.plot(fpr1, tpr1 ,label='++ cuu (area = {:.4f})'.format(roc_auc1))
plt.plot(fpr2, tpr2 ,label='-- cuu (area = {:.4f})'.format(roc_auc2))
plt.plot(fpr3, tpr3 ,label='++ cqu (area = {:.4f})'.format(roc_auc3))
plt.plot(fpr4, tpr4 ,label='-- cqu (area = {:.4f})'.format(roc_auc4))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig(path_SvsB + "ROC-Curve.png")
plt.show()
